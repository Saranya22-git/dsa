# %%
# Loop

for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Loop + Variable update

total=0
for i in range(1,4):
    total=total+i
print(total)
# Out:
# 6

# %%
# Repeated multiplication

x=1
for i in range(1,5):
    x=x*2
print(x)
# Out:
# 16
